# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
import re

def comprehensive_preprocessing(text):
    # Menghapus URL
    text = re.sub(r"http\S+|www\S+|https\S+", '', text, flags=re.MULTILINE)

    # Menghapus karakter khusus dan angka
    text = re.sub(r'\W|[\d_]', ' ', text)

    # Menghapus kata yang berulang
    text = re.sub(r'\b(\w+)( \1\b)+', r'\1', text)

    # Menghapus emoji atau simbol khusus
    emoji_pattern = re.compile(
        "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F700-\U0001F77F"  # alchemical symbols
        u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        u"\U0001FA00-\U0001FA6F"  # Chess Symbols
        u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        u"\U00002702-\U000027B0"  # Dingbats
        u"\U000024C2-\U0001F251"
        "]+"
    )

    text = emoji_pattern.sub(r'', text)

    # Menghapus tanda baca
    text = re.sub(r'[^\w\s#]', ' ', text)

    # Menghapus kata-kata singkat
    text = ' '.join([word for word in text.split() if len(word) > 2])

    # Menghapus mention
    text = re.sub(r'@\w+', '', text)

    # Mengonversi teks ke huruf kecil
    text = text.lower()

    # Menghapus spasi berlebih
    text = ' '.join(text.split())

    return text

# %%
df = pd.read_csv('data/dataset_jurnal_indo_5k.csv')

df['data'] = df['title'] + df['abstrac_clean']
df.head(500)
# Out:
#        jid                                          aid        date  \
# 0    10004      oai:ojs2.profood.unram.ac.id:article/11  2017-03-17
# 1    10004      oai:ojs2.profood.unram.ac.id:article/12  2017-03-17
# 2    10004      oai:ojs2.profood.unram.ac.id:article/13  2017-03-17
# 3    10004      oai:ojs2.profood.unram.ac.id:article/14  2017-03-17
# 4    10004      oai:ojs2.profood.unram.ac.id:article/15  2017-03-17
# ..     ...                                          ...         ...
# 495   1000  oai:ojs.ejournal.unsrat.ac.id:article/41029  2022-07-30
# 496   1000  oai:ojs.ejournal.unsrat.ac.id:article/41044  2022-07-30
# 497   1000  oai:ojs.ejournal.unsrat.ac.id:article/41102  2022-07-27
# 498   1000  oai:ojs.ejournal.unsrat.ac.id:article/41279  2022-08-25
# 499   1000  oai:ojs.ejournal.unsrat.ac.id:article/41503  2022-08-07
#
#                                                  title  \
# 0    EFEKTIVITAS PERLAKUAN OZON TERHADAP MUTU KANGK...
# 1    PENYIMPANAN MANGGA  SECARA  MODIFIKASI ATMOSFI...
# 2    PENGARUH RASIO SUSU FULL CREAM  DENGAN JAGUNG ...
# 3    KAJIAN MUTU DAN DAYA SIMPAN KEJU MOZZARELLA PR...
# 4    PENGARUH PENAMBAHAN PROBIOTIK (Lactobacillus c...
# ..                                                 ...
# 495  Oral Manifestation of Sexual Transmitted Diseases
# 496  Behavioral Changes in Cleansing Complete Dentu...
# 497                Management of Exfoliative Cheilitis
# 498  Management of Primary Tooth in Agenesis of Lat...
# 499  Effect of Servo Tomato (Solanum lycopersicum) ...
#
#                                                   desc  \
# 0    The aimed of this research was to investigate ...
# 1    Modified Atmosphere Storage of Mango with Ca(O...
# 2    The aimed of this research was to determine th...
# 3    This study aims to determine the best probioti...
# 4    Mozzarella cheese is one of the Italian cheese...
# ..                                                 ...
# 495  Abstract: Sexually transmitted diseases (STDs)...
# 496  Abstract: Tooth loss experienced by elderly ca...
# 497  Abstract: Cheilitis is an inflammation of the ...
# 498  Abstract: Agenesis is commonly found in maxill...
# 499  Abstract: Herbal medicines such as Servo tomat...
#
#                                          abstrac_clean  \
# 0    penelitian ini bertujuan untuk menentukan meto...
# 1     penelitian tentang penyimpanan mangga secara ...
# 2     penelitian ini bertujuan untuk mengetahui pen...
# 3     penelitian ini bertujuan untuk mengetahui kon...
# 4     keju mozarella salah satu keju khas italia ya...
# ..                                                 ...
# 495   penyakit menular seksual pms merupakan infeks...
# 496   kehilangan gigi yang dialami oleh lanjut usia...
# 497   keilitis adalah adanya inflamasi pada vermili...
# 498   umumnya agenesis dijumpai pada gigi insisivus...
# 499   tanaman herbal seperti tomat servo yang menga...
#
#                                                   data
# 0    EFEKTIVITAS PERLAKUAN OZON TERHADAP MUTU KANGK...
# 1    PENYIMPANAN MANGGA  SECARA  MODIFIKASI ATMOSFI...
# 2    PENGARUH RASIO SUSU FULL CREAM  DENGAN JAGUNG ...
# 3    KAJIAN MUTU DAN DAYA SIMPAN KEJU MOZZARELLA PR...
# 4    PENGARUH PENAMBAHAN PROBIOTIK (Lactobacillus c...
# ..                                                 ...
# 495  Oral Manifestation of Sexual Transmitted Disea...
# 496  Behavioral Changes in Cleansing Complete Dentu...
# 497  Management of Exfoliative Cheilitis keilitis a...
# 498  Management of Primary Tooth in Agenesis of Lat...
# 499  Effect of Servo Tomato (Solanum lycopersicum) ...
#
# [500 rows x 7 columns]

# %%
data = df['data'].astype(str).apply(comprehensive_preprocessing)
data
# Out:
# 0       efektivitas perlakuan ozon terhadap mutu kangk...
# 1       penyimpanan mangga secara modifikasi atmosfir ...
# 2       pengaruh rasio susu full cream dengan jagung m...
# 3       kajian mutu dan daya simpan keju mozzarella pr...
# 4       pengaruh penambahan probiotik lactobacillus ca...
#                               ...
# 4995    efek pemberian depo medroxy progesteron acetat...
# 4996    faktor yang berhubungan dengan stigma masyarak...
# 4997    faktor faktor yang mempengaruhi kepatuhan peng...
# 4998    kurma sebagai alternatif untuk meningkatkan ka...
# 4999    faktor penyebab ketidaklengkapan pengisian dok...
# Name: data, Length: 5000, dtype: object

# %%
df['data_clean'] = data
# df.to_csv('dataset_clean_5k.csv')
df

data_jid = df[df['jid']==10004]
data_jid

data = data_jid['data'].astype(str).apply(comprehensive_preprocessing)

# %%
data_jid
# Out:
#        jid                                       aid        date  \
# 0    10004   oai:ojs2.profood.unram.ac.id:article/11  2017-03-17
# 1    10004   oai:ojs2.profood.unram.ac.id:article/12  2017-03-17
# 2    10004   oai:ojs2.profood.unram.ac.id:article/13  2017-03-17
# 3    10004   oai:ojs2.profood.unram.ac.id:article/14  2017-03-17
# 4    10004   oai:ojs2.profood.unram.ac.id:article/15  2017-03-17
# ..     ...                                       ...         ...
# 104  10004  oai:ojs2.profood.unram.ac.id:article/205  2022-01-15
# 105  10004  oai:ojs2.profood.unram.ac.id:article/209  2022-01-24
# 106  10004  oai:ojs2.profood.unram.ac.id:article/215  2021-12-31
# 107  10004  oai:ojs2.profood.unram.ac.id:article/225  2022-01-15
# 108  10004  oai:ojs2.profood.unram.ac.id:article/226  2021-12-31
#
#                                                  title  \
# 0    EFEKTIVITAS PERLAKUAN OZON TERHADAP MUTU KANGK...
# 1    PENYIMPANAN MANGGA  SECARA  MODIFIKASI ATMOSFI...
# 2    PENGARUH RASIO SUSU FULL CREAM  DENGAN JAGUNG ...
# 3    KAJIAN MUTU DAN DAYA SIMPAN KEJU MOZZARELLA PR...
# 4    PENGARUH PENAMBAHAN PROBIOTIK (Lactobacillus c...
# ..                                                 ...
# 104  KARAKTERISASI BAKTERI LIPOLITIK Bacillus sp. P...
# 105  Kajian Penambahan Ubi Jalar Ungu (Ipomoea bata...
# 106  KARAKTERISASI MUTU TEH HITAM METODE CTC (Crush...
# 107  ANALISIS MUTU KIMIA, MIKROBIOLOGI DAN ORGANOLE...
# 108  PENGARUH KONSENTRASI STARTER SCOBY (SYMBIOTIC ...
#
#                                                   desc  \
# 0    The aimed of this research was to investigate ...
# 1    Modified Atmosphere Storage of Mango with Ca(O...
# 2    The aimed of this research was to determine th...
# 3    This study aims to determine the best probioti...
# 4    Mozzarella cheese is one of the Italian cheese...
# ..                                                 ...
# 104  ABSTRACT\nOne of the leading enzymes having th...
# 105  ABSTRACT\nYoghurt is a drink made from the fer...
# 106  Abstract\nThis study aims to test the quality ...
# 107  ABSTRACT\nThis study was aimed to analyze the ...
# 108  ABSTRACT\nApple juice kombucha was a fermented...
#
#                                          abstrac_clean  \
# 0    penelitian ini bertujuan untuk menentukan meto...
# 1     penelitian tentang penyimpanan mangga secara ...
# 2     penelitian ini bertujuan untuk mengetahui pen...
# 3     penelitian ini bertujuan untuk mengetahui kon...
# 4     keju mozarella salah satu keju khas italia ya...
# ..                                                 ...
# 104  salah satu enzim utama berpotensi menyumbang k...
# 105  yoghurt adalah minuman yang terbuat dari prose...
# 106  penelitian ini bertujuan untuk menganalisis mu...
# 107  penelitian ini bertujuan untuk menganalisis mu...
# 108  kombucha sari apel merupakan minuman fermentas...
#
#                                                   data  \
# 0    EFEKTIVITAS PERLAKUAN OZON TERHADAP MUTU KANGK...
# 1    PENYIMPANAN MANGGA  SECARA  MODIFIKASI ATMOSFI...
# 2    PENGARUH RASIO SUSU FULL CREAM  DENGAN JAGUNG ...
# 3    KAJIAN MUTU DAN DAYA SIMPAN KEJU MOZZARELLA PR...
# 4    PENGARUH PENAMBAHAN PROBIOTIK (Lactobacillus c...
# ..                                                 ...
# 104  KARAKTERISASI BAKTERI LIPOLITIK Bacillus sp. P...
# 105  Kajian Penambahan Ubi Jalar Ungu (Ipomoea bata...
# 106  KARAKTERISASI MUTU TEH HITAM METODE CTC (Crush...
# 107  ANALISIS MUTU KIMIA, MIKROBIOLOGI DAN ORGANOLE...
# 108  PENGARUH KONSENTRASI STARTER SCOBY (SYMBIOTIC ...
#
#                                             data_clean
# 0    efektivitas perlakuan ozon terhadap mutu kangk...
# 1    penyimpanan mangga secara modifikasi atmosfir ...
# 2    pengaruh rasio susu full cream dengan jagung m...
# 3    kajian mutu dan daya simpan keju mozzarella pr...
# 4    pengaruh penambahan probiotik lactobacillus ca...
# ..                                                 ...
# 104  karakterisasi bakteri lipolitik bacillus pada ...
# 105  kajian penambahan ubi jalar ungu ipomoea batat...
# 106  karakterisasi mutu teh hitam metode ctc crushi...
# 107  analisis mutu kimia mikrobiologi dan organolep...
# 108  pengaruh konsentrasi starter scoby symbiotic c...
#
# [109 rows x 8 columns]

# %%
from gensim.models import Word2Vec
import numpy as np

# Tokenisasi deskripsi jurnal
tokenized_data = [doc.split() for doc in data]

# Membangun model Word2Vec
word2vec_model = Word2Vec(sentences=tokenized_data, vector_size=100, window=5, min_count=1, workers=4)

# Melakukan vektorisasi dengan Word2Vec
word_vectors = word2vec_model.wv

# Menciptakan vektor rata-rata untuk setiap dokumen
def document_vector(doc):
    # Mengambil vektor kata-kata dalam dokumen yang ada dalam model Word2Vec
    vectors = [word2vec_model.wv[word] for word in doc if word in word2vec_model.wv]
    # Mengembalikan vektor rata-rata dari vektor kata-kata
    return np.mean(vectors, axis=0)

# Menghasilkan vektor untuk setiap dokumen
document_vectors = [document_vector(doc) for doc in tokenized_data]

# Konversi ke dalam format array numpy
X = np.array(document_vectors)

# %%
# Menentukan jumlah cluster yang diinginkan
jumlah_cluster = 1

# Menerapkan algoritma K-Means
kmeans = KMeans(n_clusters=jumlah_cluster)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=1)

# %%
# Mendapatkan koordinat pusat cluster
centroid = kmeans.cluster_centers_

# Menghitung jarak antara setiap titik data dengan centroid
jarak_ke_centroid = np.sqrt(np.sum((X - centroid)**2, axis=1))

# Menentukan batas jarak yang dianggap sebagai "outscoop"
# Misalnya, jika ingin menentukan data yang berjarak lebih dari 2 kali standar deviasi dari centroid
outscoop_threshold = np.mean(jarak_ke_centroid) + 2 * np.std(jarak_ke_centroid)

# Memisahkan data yang masih masuk dalam "scoop" dan "outscoop"
scoop_data = X[jarak_ke_centroid <= outscoop_threshold]
outscoop_data = X[jarak_ke_centroid > outscoop_threshold]

print("Data dalam scoop:")
print(scoop_data)

print("\nData outscoop:")
print(outscoop_data)
# Out:
# Data dalam scoop:
# [[-0.16818948  0.23522201  0.05642592 ... -0.27356035  0.13380362
#   -0.11957976]
#  [-0.18586944  0.25772876  0.06172422 ... -0.29832226  0.146414
#   -0.13188063]
#  [-0.20396185  0.28494403  0.06942155 ... -0.33184692  0.16339214
#   -0.14568621]
#  ...
#  [-0.15657261  0.21976443  0.04987549 ... -0.2538035   0.12381264
#   -0.10978142]
#  [-0.2087701   0.2915413   0.06906721 ... -0.3361167   0.16673583
#   -0.14824517]
#  [-0.18525355  0.25998446  0.06094866 ... -0.30099258  0.14822298
#   -0.13097174]]
#
# Data outscoop:
# [[-2.48089179e-01  3.48279148e-01  8.18433389e-02 -3.71618420e-02
#    1.01136833e-01 -4.33036000e-01  2.67734230e-01  5.75399399e-01
#   -4.03790027e-01 -2.13743135e-01 -6.56365529e-02 -5.11222422e-01
#   -8.83243755e-02  2.63241082e-01  1.12196654e-01 -3.35010648e-01
#    1.10444583e-01 -3.18517357e-01 -2.55695194e-01 -7.51970291e-01
#    2.91588336e-01  2.53958106e-01  1.63528070e-01 -2.43900642e-01
#   -1.20855860e-01  2.91259885e-02 -1.58911228e-01 -1.65748388e-01
#   -4.47957039e-01  9.69059765e-02  3.61207634e-01  4.66490090e-02
#    7.29760081e-02 -2.74405658e-01 -1.99740708e-01  4.87995565e-01
#    1.68687835e-01 -9.48466267e-03 -3.22875530e-01 -5.16572356e-01
#    1.84388254e-02 -3.08494985e-01 -9.82345492e-02  1.21070445e-01
#    2.76866019e-01 -1.56024903e-01 -1.87881291e-01  6.18307525e-03
#    3.49479944e-01  1.35863602e-01  1.89436406e-01 -2.47401357e-01
#    3.70431803e-02  6.87254518e-02 -2.44775847e-01  2.14248635e-02
#    3.31732035e-01  1.13202976e-02 -3.83870572e-01  7.00680465e-02
#   -2.66990662e-02  1.07032061e-01  2.65458580e-02 -1.75072938e-01
#   -4.09929067e-01  4.10775274e-01  2.97944546e-01  4.67264473e-01
#   -7.57366121e-01  5.01006722e-01 -2.16143101e-01  2.71195043e-02
#    4.08931196e-01 -1.96848273e-01  3.81226122e-01  1.50024444e-01
#    9.45699438e-02  1.61876548e-02 -3.15142870e-01  5.90153635e-02
#   -3.71267617e-01 -8.65759179e-02 -4.72633630e-01  4.65414882e-01
#   -1.89388096e-01  1.05994619e-01  1.04227997e-01  4.22333747e-01
#    4.37083960e-01  1.80539727e-01  6.56487584e-01  2.03849316e-01
#    8.59866589e-02 -7.61251822e-02  7.16470182e-01  3.07904392e-01
#    1.86738893e-01 -4.07946110e-01  1.99175850e-01 -1.76135033e-01]
#  [-1.49524570e-01  2.07462907e-01  4.88808155e-02 -2.14816518e-02
#    5.82124032e-02 -2.55429268e-01  1.57502979e-01  3.42069834e-01
#   -2.35616028e-01 -1.26963079e-01 -3.84551845e-02 -3.01399440e-01
#   -5.25377542e-02  1.55701578e-01  6.76306486e-02 -1.99520156e-01
#    6.33676946e-02 -1.89574271e-01 -1.50967255e-01 -4.40904379e-01
#    1.72160253e-01  1.48942798e-01  9.38009098e-02 -1.44542783e-01
#   -6.96644112e-02  1.86988730e-02 -9.42292735e-02 -9.75987017e-02
#   -2.63979286e-01  5.79762571e-02  2.10539415e-01  2.57850122e-02
#    4.28760983e-02 -1.61862671e-01 -1.15666606e-01  2.88542002e-01
#    1.01975150e-01 -2.48564268e-03 -1.90886781e-01 -3.03290397e-01
#    1.00092534e-02 -1.82439357e-01 -6.09149672e-02  7.20609277e-02
#    1.63695544e-01 -9.39453095e-02 -1.10336654e-01  4.12905170e-03
#    2.05371827e-01  8.24069753e-02  1.11676313e-01 -1.45100415e-01
#    2.29023844e-02  4.14406508e-02 -1.44079447e-01  1.28998943e-02
#    1.95791453e-01  6.98703714e-03 -2.26238564e-01  4.24911156e-02
#   -1.54563282e-02  6.35696128e-02  1.42927626e-02 -1.04009852e-01
#   -2.41263017e-01  2.42943332e-01  1.78444356e-01  2.75719583e-01
#   -4.47543085e-01  2.97399342e-01 -1.26299664e-01  1.50546413e-02
#    2.41893038e-01 -1.16749980e-01  2.20996499e-01  9.04327706e-02
#    5.58226071e-02  8.36894661e-03 -1.85537413e-01  3.61931436e-02
#   -2.18559712e-01 -5.05819917e-02 -2.75789469e-01  2.72129923e-01
#   -1.09174706e-01  6.45139888e-02  6.00082316e-02  2.50209898e-01
#    2.59981275e-01  1.07885428e-01  3.89009893e-01  1.20215826e-01
#    5.09597808e-02 -4.44467962e-02  4.24245447e-01  1.82947919e-01
#    1.09574907e-01 -2.39849195e-01  1.16910584e-01 -1.04620181e-01]
#  [-1.29675210e-01  1.81769982e-01  4.20212001e-02 -1.88522674e-02
#    5.23550510e-02 -2.24426582e-01  1.36810169e-01  2.98822314e-01
#   -2.08737254e-01 -1.08899817e-01 -3.49091105e-02 -2.64352947e-01
#   -4.72271889e-02  1.35936931e-01  5.78781292e-02 -1.72670141e-01
#    5.74329272e-02 -1.66039884e-01 -1.31285220e-01 -3.88789773e-01
#    1.51807085e-01  1.28603324e-01  8.22205618e-02 -1.27341464e-01
#   -6.24612644e-02  1.63449999e-02 -8.22869837e-02 -8.66402611e-02
#   -2.31309071e-01  5.14333621e-02  1.87017471e-01  2.20482685e-02
#    3.70852016e-02 -1.40407085e-01 -1.00487664e-01  2.51385033e-01
#    8.80236998e-02 -1.31992798e-03 -1.65518269e-01 -2.65680611e-01
#    9.73396748e-03 -1.59801587e-01 -5.33209741e-02  6.49139881e-02
#    1.42579406e-01 -8.19339901e-02 -9.61248875e-02  4.13714629e-03
#    1.80846214e-01  7.15854093e-02  9.78850648e-02 -1.27425641e-01
#    2.03712508e-02  3.74102741e-02 -1.27009764e-01  1.25338947e-02
#    1.71420172e-01  5.88538777e-03 -2.00089172e-01  3.65064144e-02
#   -1.43907620e-02  5.78411594e-02  1.16535602e-02 -9.18985307e-02
#   -2.11678579e-01  2.12186590e-01  1.55420914e-01  2.41222605e-01
#   -3.91471982e-01  2.61917084e-01 -1.11729465e-01  1.23206349e-02
#    2.10512221e-01 -1.00877315e-01  1.94750860e-01  7.85357654e-02
#    4.72931713e-02  7.35498033e-03 -1.63054556e-01  3.01889293e-02
#   -1.91454783e-01 -4.44641374e-02 -2.43643269e-01  2.39164382e-01
#   -9.60765556e-02  5.53341657e-02  5.14449850e-02  2.19165057e-01
#    2.27591425e-01  9.44100171e-02  3.39501679e-01  1.04856282e-01
#    4.43206728e-02 -4.14798222e-02  3.70361209e-01  1.59905970e-01
#    9.63744968e-02 -2.10000902e-01  1.02920771e-01 -9.15256217e-02]
#  [-1.34045780e-01  1.85427934e-01  4.34814021e-02 -1.94478501e-02
#    5.21542393e-02 -2.30531141e-01  1.39506161e-01  3.06070387e-01
#   -2.13134184e-01 -1.13440327e-01 -3.46963480e-02 -2.70757169e-01
#   -4.87880744e-02  1.39888719e-01  6.07516617e-02 -1.77853063e-01
#    5.79016395e-02 -1.69909686e-01 -1.34658515e-01 -3.97030443e-01
#    1.55596852e-01  1.33335352e-01  8.50061178e-02 -1.29067332e-01
#   -6.39546067e-02  1.71691757e-02 -8.51620361e-02 -8.86420086e-02
#   -2.36881375e-01  5.23810610e-02  1.91422090e-01  2.40542758e-02
#    3.86803560e-02 -1.44962385e-01 -1.02461815e-01  2.57722050e-01
#    9.15419832e-02 -1.25092326e-03 -1.71005815e-01 -2.71600783e-01
#    8.39657243e-03 -1.64683700e-01 -5.48563525e-02  6.54858276e-02
#    1.46004289e-01 -8.40655416e-02 -9.84802842e-02  5.14034880e-03
#    1.86136886e-01  7.29625002e-02  1.00646295e-01 -1.30507827e-01
#    1.98674127e-02  3.70436721e-02 -1.28506526e-01  1.30924787e-02
#    1.75789550e-01  5.80956507e-03 -2.04284921e-01  3.77889499e-02
#   -1.41404057e-02  5.80484159e-02  1.16925072e-02 -9.44365487e-02
#   -2.16642082e-01  2.16720611e-01  1.58624336e-01  2.47917131e-01
#   -3.99240851e-01  2.67671168e-01 -1.13905385e-01  1.33667495e-02
#    2.16240525e-01 -1.04306541e-01  2.00762898e-01  8.15561861e-02
#    4.86726314e-02  6.37027621e-03 -1.65548891e-01  3.04232985e-02
#   -1.96663052e-01 -4.57883663e-02 -2.48102307e-01  2.45636538e-01
#   -9.86826941e-02  5.73828220e-02  5.19556180e-02  2.24015236e-01
#    2.31936172e-01  9.71527696e-02  3.49440813e-01  1.07078373e-01
#    4.59319800e-02 -4.01758663e-02  3.79347473e-01  1.62691906e-01
#    9.81158763e-02 -2.15265065e-01  1.03403628e-01 -9.38581154e-02]
#  [-1.48045748e-01  2.05861375e-01  4.92753536e-02 -2.14743093e-02
#    5.97395077e-02 -2.56367654e-01  1.57353893e-01  3.41410637e-01
#   -2.36677289e-01 -1.25879079e-01 -3.86568792e-02 -3.00858498e-01
#   -5.35391271e-02  1.54583201e-01  6.74367324e-02 -1.97886243e-01
#    6.35768473e-02 -1.88462585e-01 -1.50957882e-01 -4.41163272e-01
#    1.73843801e-01  1.48406357e-01  9.47557166e-02 -1.43977538e-01
#   -7.17205331e-02  1.82776637e-02 -9.38511714e-02 -9.79539081e-02
#   -2.64192700e-01  5.64295650e-02  2.13545725e-01  2.51581743e-02
#    4.35358100e-02 -1.60780773e-01 -1.14878535e-01  2.88052827e-01
#    1.02482475e-01 -3.41354450e-03 -1.90652162e-01 -3.03439260e-01
#    9.16711148e-03 -1.82674035e-01 -6.08376861e-02  7.25169331e-02
#    1.61882058e-01 -9.32914540e-02 -1.08359039e-01  3.86829395e-03
#    2.06901625e-01  8.32084194e-02  1.11182384e-01 -1.43786818e-01
#    2.17085853e-02  4.10049558e-02 -1.43240809e-01  1.39011266e-02
#    1.94713190e-01  7.02624628e-03 -2.25287452e-01  4.09636572e-02
#   -1.56168435e-02  6.38624355e-02  1.48603162e-02 -1.04633488e-01
#   -2.41210967e-01  2.42107391e-01  1.77577257e-01  2.75520980e-01
#   -4.46309626e-01  2.98588842e-01 -1.27345607e-01  1.44241275e-02
#    2.41525441e-01 -1.15522593e-01  2.23140314e-01  8.98142159e-02
#    5.47058173e-02  8.21413379e-03 -1.85524687e-01  3.47289369e-02
#   -2.18162239e-01 -5.15139997e-02 -2.76876897e-01  2.73016542e-01
#   -1.10083222e-01  6.45415112e-02  5.78181669e-02  2.48895034e-01
#    2.58140266e-01  1.08021423e-01  3.87677819e-01  1.18497998e-01
#    4.96400110e-02 -4.62549590e-02  4.24444288e-01  1.81339800e-01
#    1.09159186e-01 -2.39388883e-01  1.16840504e-01 -1.05318859e-01]
#  [-1.32482544e-01  1.85488939e-01  4.29703258e-02 -2.00744420e-02
#    5.20608164e-02 -2.29388684e-01  1.38946548e-01  3.05670708e-01
#   -2.11451903e-01 -1.12330914e-01 -3.40896472e-02 -2.69251198e-01
#   -4.75970767e-02  1.38635069e-01  5.86584806e-02 -1.77750394e-01
#    5.75742871e-02 -1.69935971e-01 -1.34033605e-01 -3.96102339e-01
#    1.55451000e-01  1.32906765e-01  8.33777040e-02 -1.29727334e-01
#   -6.46454468e-02  1.65669974e-02 -8.51799175e-02 -8.88594091e-02
#   -2.34658211e-01  5.27461469e-02  1.90639988e-01  2.34573185e-02
#    3.95339057e-02 -1.44022331e-01 -1.03126973e-01  2.57358730e-01
#    9.14332196e-02  1.66361860e-04 -1.70867950e-01 -2.71649212e-01
#    8.93948693e-03 -1.63918227e-01 -5.52854687e-02  6.50994405e-02
#    1.46825463e-01 -8.46935436e-02 -9.74726602e-02  4.75746207e-03
#    1.83304474e-01  7.34931827e-02  9.87569764e-02 -1.30503029e-01
#    2.11810265e-02  3.75225507e-02 -1.27788886e-01  1.12318648e-02
#    1.74335703e-01  4.65652440e-03 -2.02662066e-01  3.80691066e-02
#   -1.46472417e-02  5.80741465e-02  1.24192005e-02 -9.35542658e-02
#   -2.15189561e-01  2.17636213e-01  1.60988510e-01  2.46379167e-01
#   -3.99091423e-01  2.67335743e-01 -1.13088347e-01  1.34109361e-02
#    2.15796113e-01 -1.04798600e-01  1.98587671e-01  7.95281604e-02
#    4.87410054e-02  7.62817403e-03 -1.64548859e-01  3.03820744e-02
#   -1.95776060e-01 -4.48205210e-02 -2.48222128e-01  2.43260726e-01
#   -9.66990665e-02  5.64462841e-02  5.14810644e-02  2.23474979e-01
#    2.31498525e-01  9.68157426e-02  3.47088784e-01  1.07187137e-01
#    4.70024310e-02 -4.08971421e-02  3.79256755e-01  1.60559863e-01
#    9.74742174e-02 -2.13525087e-01  1.04253292e-01 -9.35419649e-02]]

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sklearn.manifold import TSNE
# import numpy as np

# def plot_vector_distribution(vector_matrix, kmeans_labels):
#     tsne = TSNE(random_state=0)
#     tsne_result = tsne.fit_transform(vector_matrix)

#     df_tsne = pd.DataFrame(tsne_result, columns=['Dimension 1', 'Dimension 2'])
#     df_tsne['Cluster Label'] = kmeans_labels

#     cluster_palette = sns.color_palette('tab10', n_colors=len(np.unique(kmeans_labels)))
#     plt.figure(figsize=(8, 6))
#     sns.scatterplot(x='Dimension 1', y='Dimension 2', hue='Cluster Label', data=df_tsne, palette=cluster_palette)
    
#     # Menambahkan centroid ke dalam plot
#     centroids = []
#     for label in np.unique(kmeans_labels):
#         centroid = np.mean(tsne_result[kmeans_labels == label], axis=0)
#         centroids.append(centroid)
#     centroids = np.array(centroids)
#     plt.scatter(centroids[:, 0], centroids[:, 1], marker='^', c='red', s=100, label='Centroids')
    
#     plt.title('t-SNE Latent Representation with Centroids')
#     plt.xlabel('Dimension 1')
#     plt.ylabel('Dimension 2')
#     plt.legend()
#     plt.show()

# plot_vector_distribution(X, kmeans.labels_)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np

def plot_vector_distribution(vector_representation, kmeans_labels):
    pca = PCA(n_components=2, random_state=0)
    pca_result = pca.fit_transform(vector_representation)

    df_pca = pd.DataFrame(pca_result, columns=['Dimension 1', 'Dimension 2'])
    df_pca['Cluster Label'] = kmeans_labels

    cluster_palette = sns.color_palette('tab10', n_colors=len(np.unique(kmeans_labels)))
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x='Dimension 1', y='Dimension 2', hue='Cluster Label', data=df_pca, palette=cluster_palette)
    
    # Menambahkan centroid ke dalam plot
    centroids = []
    for label in np.unique(kmeans_labels):
        centroid = np.mean(pca_result[kmeans_labels == label], axis=0)
        centroids.append(centroid)
    centroids = np.array(centroids)
    plt.scatter(centroids[:, 0], centroids[:, 1], marker='^', c='red', s=50, label='Centroids')
    
    plt.title('PCA Latent Representation with Centroids')
    plt.xlabel('Dimension 1')
    plt.ylabel('Dimension 2')
    plt.legend()
    plt.show()

plot_vector_distribution(X, kmeans.labels_)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np

def plot_vector_distribution(vector_representation, kmeans_labels, scoop_labels):
    pca = PCA(n_components=2, random_state=0)
    pca_result = pca.fit_transform(vector_representation)

    df_pca = pd.DataFrame(pca_result, columns=['Dimension 1', 'Dimension 2'])
    # df_pca['Cluster Label'] = kmeans_labels
    df_pca['Scoop Label'] = scoop_labels

    cluster_palette = sns.color_palette('tab10', n_colors=len(np.unique(kmeans_labels)))
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x='Dimension 1', y='Dimension 2', hue='Scoop Label', style='Scoop Label', data=df_pca, palette=cluster_palette, markers=['o', 'X'], legend='full')
    
    # Menambahkan centroid ke dalam plot
    centroids = []
    for label in np.unique(kmeans_labels):
        centroid = np.mean(pca_result[kmeans_labels == label], axis=0)
        centroids.append(centroid)
    centroids = np.array(centroids)
    plt.scatter(centroids[:, 0], centroids[:, 1], marker='^', c='red', s=50, label='Centroids')
    
    plt.title('PCA Latent Representation with Centroids')
    plt.xlabel('Dimension 1')
    plt.ylabel('Dimension 2')
    plt.legend()
    plt.show()

# Menentukan label untuk scoop dan outscoop
scoop_labels = np.ones(len(X))
scoop_labels[jarak_ke_centroid > outscoop_threshold] = -1

plot_vector_distribution(X, kmeans.labels_, scoop_labels)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_21956\371883579.py:17: UserWarning:
# The palette list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(x='Dimension 1', y='Dimension 2', hue='Scoop Label', style='Scoop Label', data=df_pca, palette=cluster_palette, markers=['o', 'X'], legend='full')

# %%
import pandas as pd

# Membuat DataFrame dengan data teks dan label scoop
df = pd.DataFrame({'Data': data_jid['data'].astype(str).apply(comprehensive_preprocessing),
                   'Label': scoop_labels})

# Memisahkan data dalam scoop dan outscoop
inScoop_df = df[df['Label'] == 1]
outScoop_df = df[df['Label'] == -1]

print("Data dalam scoop:")
print(inScoop_df)

print("\nData outscoop:")
print(outScoop_df)
# Out:
# Data dalam scoop:
#                                                   Data  Label
# 0    efektivitas perlakuan ozon terhadap mutu kangk...    1.0
# 1    penyimpanan mangga secara modifikasi atmosfir ...    1.0
# 2    pengaruh rasio susu full cream dengan jagung m...    1.0
# 3    kajian mutu dan daya simpan keju mozzarella pr...    1.0
# 4    pengaruh penambahan probiotik lactobacillus ca...    1.0
# ..                                                 ...    ...
# 103  potensi pembentukan pati resisten dan antioksi...    1.0
# 105  kajian penambahan ubi jalar ungu ipomoea batat...    1.0
# 106  karakterisasi mutu teh hitam metode ctc crushi...    1.0
# 107  analisis mutu kimia mikrobiologi dan organolep...    1.0
# 108  pengaruh konsentrasi starter scoby symbiotic c...    1.0
#
# [103 rows x 2 columns]
#
# Data outscoop:
#                                                   Data  Label
# 18   pengaruh rasio tepung biji kecipir dengan tepu...   -1.0
# 31   prevalensi status gizi pada siswa siswi smk pr...   -1.0
# 34   smart cacao dryer berbasis hybrid sebagai alat...   -1.0
# 56   identifikasi potensi bahaya dan pemantauan cri...   -1.0
# 63   gula darah dan berat badan tikus putih spraque...   -1.0
# 104  karakterisasi bakteri lipolitik bacillus pada ...   -1.0
